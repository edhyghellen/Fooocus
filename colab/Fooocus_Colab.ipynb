# %% [markdown]
# # 🔮 Fooocus - Google Colab Launcher
# This notebook will install and launch Fooocus directly in Google Colab. No setup needed!

# %%
#@title 🧩 Install dependencies
# !apt -y install -qq aria2
# !pip install -q xformers triton accelerate torch torchvision torchaudio
# !pip install -q gradio==4.20.1

# %%
#@title 📦 Clone Fooocus repo
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd Fooocus

# %%
#@title 💾 Download models (this may take a few minutes)
# !python entry_with_update.py --just-download --no-half

# %%
#@title 🚀 Start Fooocus Web UI
# !python entry_with_update.py --listen
